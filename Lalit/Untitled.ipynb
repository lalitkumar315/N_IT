# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 number
#
# NameError: name 'number' is not defined

# %%
a
# Out:
# 10

# %%
lalit = 100
lalit
# Out:
# 100

# %%
n1 = 100

# %%
n1
# Out:
# 100
