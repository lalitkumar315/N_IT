# %% [markdown]
# - python executes a code, based on come conditions
#
# - those conditions represent with **if-else-elif**
#
# - every condition provide **True or False**
#
# - True means execution accepted.
#
# - false neans execution not accepted.

# %% [markdown]
# **if**

# %%
a = 10
a
# Out:
# 10

# %%
a==10# 10==10
# Out:
# True

# %%
Name == 'python'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Name == 'python'
#
# NameError: name 'Name' is not defined

# %%
name = 'lalit'
name == 'python'
# Out:
# False

# %%
'a' > 'A' # a= 9  A=65
# Out:
# True

# %%
'p'>'P'
# Out:
# True

# %%
ord('a'),ord('A')
# Out:
# (97, 65)

# %%
chr(120)
# Out:
# 'x'

# %% [markdown]
# **SYNTAX**

# %% [markdown]
# code1
# if <condition>:
#     code3 here
#     code4 here
# code2
#
# #code1 and code2 are outside the if
# #code3 and code4 are inside the if

# %%
a=100
if a == 100:
    print('Hello')
# Out:
# Hello

# %% [markdown]
# **indentation**
# - adding space before the code
# - when you observe a colon(:), the imidiate lines expect a space
# - if we dont provide the space or not proper space we will get a **indentation error**

# %%
a=100
if a == 100:
    print('Hello')
    print('hi') #shift + tab === tab

# need comment : CTRL+/
# Out:
# Hello
# hi

# %%
# backsapace+enter
# tab
# space bar

# %%
if True:
    print('hello')
# Out:
# hello

# %%
if False:            #No Entry
    print('hello')

# %%
print('Hi')
if True:
    print('Hello')
print('Bye')
# Out:
# Hi
# Hello
# Bye

# %%
print('Hi')
if False:
    print('Hello')
    print('hey')
print('Bye')
# Out:
# Hi
# Bye

# %%
print(1)
if True:
    print(2)
    if False:
        if True:
            print(3)
        print(4)
    print(5)
print(6)
# Out:
# 1
# 2
# 5
# 6

# %%
print(1)
if False:
    print(2)
if True:
    if True:
        print(3)
    print(4)
print(5)
print(6)
# Out:
# 1
# 3
# 4
# 5
# 6

# %% [markdown]
# **id else**
# - when condition is true python executes the code inside the **if** block
# - otherwise **else block**
# - so else does not require any condition to specify

# %%
if <condition>:
    <code>
else:
    <code>

# %%
if False:
    print('Good Condition')
    print('Hello')
else:
    print('bad Condition')
    print('Bye')
# Out:
# bad Condition
# Bye

# %%
if False:
    print('Good Condition')
    print('Hello')
print('Why are you in the middle')
else:
    print('bad Condition')
    print('Bye')
# Out:
#   Cell In[51], line 5
#     else:
#     ^
# SyntaxError: invalid syntax
