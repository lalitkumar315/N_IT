# %%
#this file is open from seession 3

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lalit\\OneDrive\\Documents\\Naresh_IT\\Python_Session'

# %% [markdown]
# ## DATA TYPES
# - In python we have some inbuilt data types are available
#     - integer: int
#     - float
#     - bool
#     - str
#     - list
#     - tuple
#     - dict
#     - complex
#     - range
#     - set
#     - frozenset
#     - bytes
#     - bytearray
#     - memoryview
#     - None

# %%
n1= 100
type(n1)
# Out:
# int

# %% [markdown]
# - if we want to know any type of data or variable we will use
#     - type function

# %% [markdown]
# **float**
# - float means decimal value representation

# %%
n2 = 100.5
type(n2)
# Out:
# float

# %% [markdown]
# **exponential data**

# %%
1e1
# Out:
# 10.0

# %%
1e1,1e+1
2e2,2e+2
3e3,3e+3
4e4,4e+4
# Out:
# (40000.0, 40000.0)

# %%
1e-1
# Out:
# 0.1

# %%
1e*1
# Out:
#   Cell In[6], line 1
#     1e*1
#     ^
# SyntaxError: invalid decimal literal

# %%
1e\1
# Out:
#   Cell In[7], line 1
#     1e\1
#     ^
# SyntaxError: invalid decimal literal

# %%
1e/1
# Out:
#   Cell In[8], line 1
#     1e/1
#     ^
# SyntaxError: invalid decimal literal

# %%
city = "hydrabad"
type(city)
# Out:
# str

# %%
city = 'bbsr"
# Out:
#   Cell In[10], line 1
#     city = 'bbsr"
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1 = 'hello'
len(s1)
# Out:
# 5

# %%
s2 = 'hello  '
len(s2)
# Out:
# 7

# %%
print(s1)
# Out:
# hello

# %%
s1,s2
# Out:
# ('hello', '')

# %%
print(s1)
print(s2)
# Out:
# hello
# hello

# %%
s2 = ''
len(s2)
# Out:
# 0

# %%
print("I like 'Python'")
# Out:
# I like 'Python'

# %% [markdown]
# - Strings can be **single quotes**
# - Strings can be **double quotes**
# - python by default use **single quotes** only
# - when printing the string we need to be careful
# - If we want to highlight any word, then keep the entire string in **single quotes**
#   - and highlighted in $double quoutes$ vice versa

# %% [markdown]
# ### Doc String

# %% [markdown]
# "hello how are you
# im good"  =============> fail
#
# 'hello how are you
# im good'  =============> fail
#
# '''hello how are you
# im good''' ============> pass

# %%
s1 = '''hello how are 
you im good'''
s1
# Out:
# 'hello how are \nyou im good'

# %% [markdown]
# - but triple quotes are not recomended
# - triple quotes are usedto comunicate the information
# - if any user writing triple quotes
# - this is called as **Doc String**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lalit\\OneDrive\\Documents\\Naresh_IT\\Python_Session'
