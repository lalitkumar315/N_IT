# %%
a=10
a

# %%
print(a)

# %% [markdown]
# - print is used only to see the answers

# %%
a=10
b = 20
print(a) #10
print(b) #20

# %%
a=10
b=20
print(a,b)

# %%
a,b

# %%
a= 10
b= 20
a=60,70

# %%
a

# %%
a,b =30
print(a)
print(b)

# %%
a,b = 60,70
print(a)
print(b)

# %% [markdown]
# # Variable

# %% [markdown]
# - variable means we can change the values and store the values

# %%
number = 100
number = 200
age = 15
age = 20

# %%
print(number)
print(age)

# %%
number = 100
NUMBER = 200
NUMber = 300
NUMber

# %%
number = 100
NUMBER = 200
NUMber = 300
number123 = 400
number123

# %%
number = 100
NUMBER = 200
NUMber = 300
number123 = 400
123number = 500
123number        # Syntax error

# %%
number = 100
NUMBER = 200
NUMber = 300
number123 = 400
123number = 500  # Syntax error
123number        # Syntax error
number&one = 600 # Syntax error
number526 = 100  # works

# %%
number_one = 600
number_one

# %%
areaoftriangle = 600
areaoftriangle
area_of_triangle = 800
area_of_triangle

# %%
_ = 900

# %%
_

# %%
numer one = 900 #syntax error

# %%
n1 = 100 # n1 is defined
n2 = n1 # n2 = 100
name = nareshit #

# %%
number!one = 100

# %%
number@one = 100

# %%
number#one = 100

# %%
number!$one = 100

# %%
number%one = 100

# %%
number&one = 100

# %%
number^one = 100

# %%
number*one = 100

# %%
number(one = 100

# %%
number-one = 100

# %%
number+one = 100

# %%
number one = 100

# %% [markdown]
# # Inbuilt Function

# %% [markdown]
# if = 100
# else
# true

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
sum(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sum(1,2,3)
#
# TypeError: sum() takes at most 2 arguments (3 given)

# %%
max(1,2,3)
# Out:
# 3

# %%
min(1,2,3)
# Out:
# 1

# %%
sum(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sum(1,2)
#
# TypeError: 'int' object is not iterable

# %%
len(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(1,2,3)
#
# TypeError: len() takes exactly one argument (3 given)

# %%
a = [1,2,3]

# %%
len(a)
# Out:
# 3

# %%
b = 10
c = 30

# %%
sum(b,c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sum(b,c)
#
# TypeError: 'int' object is not iterable

# %%
# black means variable
# red means string
# greens are for special purposes includes keywords

# %%
sum = 100

# %%
sum
# Out:
# 100

# %%
if = 200
# Out:
#   Cell In[17], line 1
#     if = 200
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Variable can be **upper cases**
#     - NUMBER = 100
# - Variable can't contain **special characters**
#     - Number$one = 100
# - Variable can only allow **underscore**
#     - Number_one = 100
# - Variable can not be **keywords**
#     - if = 100
# - Variables can be **Inbuilt Function** but not allowed
#     - sum = 100
