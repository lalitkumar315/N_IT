# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %% [markdown]
# - When we miss the function brackets it wil give two indications
#     - **function**
#     - **bound method**

# %%
os.getcwd()
# Out:
# 'C:\\Users\\lalit\\OneDrive\\Documents\\Naresh_IT\\Python_Session'

# %% [markdown]
# **Assignments**

# %%
# wap take three number and find the avg.
n1 = 10
n2 = 20
n3 = 30
avg = (n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
# wap ask a user calculate area of triangle 
pi = 3.14
radius = 20
area = pi * radius * radius
area
# Out:
# 1256.0

# %%
# wap calculate the area of right angle triagle
breadth = 5
height = 6
area = 0.5 * breadth * height
area
# Out:
# 15.0

# %%
# wap calculate area of rectangle
length = 7
breadth = 8
area = length * breadth 
area
# Out:
# 56

# %%
# wap to ask the user take two variable
bill = 5000
tip = 100
total = bill + tip
total
# Out:
# 5100

# %%
# wap to calculate tax
salary = 50000
tax_percent= 5
tax = salary * tax_percent/100
print(tax)
total_salary = salary - tax
total_salary
# Out:
# 2500.0
# 47500.0

# %% [markdown]
# **round**

# %%
round(9.198999,3)
# Out:
# 9.199
