# %%
a=10
b=20
a+b
# Out:
# 30

# %%
number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 number
#
# NameError: name 'number' is not defined

# %%
a

# %%
a

# %%
omkar = 100
omkar

# %%
n4 = 600

# %%
n4

# %%
# code cell indicates square bracket before cell.
# if the square bracket empty means the cell did not run.
# when we run the cell there is a number available in the square bracket.

# %%
print ("Good Morning")

# %%
import time
time.sleep(5)
print ("Good Morning")

# %%
# kernel is white color : idle state
# kernel is black color : busy state
# kernel is red color : dead state

# when kernel is busy state there is [*] mark appear in square brackets

# %%
b = 100
b

# %% [markdown]
# kernel is white color : idle state

# %% [markdown]
# code mode : esc + Y
# markdown mode : esc + M

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# - kernel is white color : idle state
#
# - kernel is black color : busy state
#
# - kernel is red color : dead state

# %% [markdown]
# <img crossorigin="anonymous" class="svelte-1qhxjcj" src="https://imgs.search.brave.com/D7Va6i2VW9krWG3Y2Cj5U4pYhypn7B0M1T-FQpvAE-M/rs:fit:500:0:1:0/g:ce/aHR0cHM6Ly9zNDE3/MjEucGNkbi5jby93/cC1jb250ZW50L3Vw/bG9hZHMvMjAyMC8x/MS9BSS1hbmQtQ2xp/bWF0ZS1TY2llbmNl/LnBuZw" alt="Discovery - AI and Climate Science" loading="lazy" data-rank="116">
